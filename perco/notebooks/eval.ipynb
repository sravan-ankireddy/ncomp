# %%
# compress
# !python /work/09004/sravana/ls6/ncomp/perco/src/compression_utils.py -V --model_path "/work/09004/sravana/ls6/ncomp/perco/src/models_chk/0.1250/cmvl_2024_full_train" compress /work/09004/sravana/ls6/ncomp/perco/res/eval/kodim13.png /work/09004/sravana/ls6/ncomp/perco/res/outputs/latents/kodim13.pkl
# Out:
# python: can't open file '/home/sa53869/perco/src/compression_utils.py': [Errno 2] No such file or directory

# %%
# decompress
# !python /home/sa53869/perco/src/compression_utils.py --model_path "/home/sa53869/perco/src/models/0.1250/cmvl_2024_full_train" decompress /home/sa53869/perco/res/outputs/latents/kodim13.pkl /home/sa53869/perco/res/outputs/reconstructions/kodim13_hat.png

# %% [markdown]
# ## Eval Kodak

# %%
# generate reconstructions, compute BPP, PSNR, MS-SSIM, LPIPS
# !python /home/sa53869/perco/src/compression_utils.py --model_path "/home/sa53869/perco/src/models/0.1250/cmvl_2024_full_train" evaluate_ds --mode 0 --in_dir "/home/sa53869/perco/src/data/CLIC2020/" --out_dir "/home/sa53869/perco/res/outputs/CLIC2020/CLIC2020_0.1250/"
# Out:
# 2024-09-09 13:06:14.971086: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/sa53869/softwares/anaconda3/envs/perco/lib/python3.8/site-packages/vector_quantize_pytorch/vector_quantize_pytorch.py:436: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /home/sa53869/softwares/anaconda3/envs/perco/lib/python3.8/site-packages/vector_quantize_pytorch/vector_quantize_pytorch.py:621: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# ...

# %%
# compute metrics (FID + KID)
# !python /home/sa53869/perco/src/compression_utils.py --model_path "/home/sa53869/perco/src/models/0.1250/cmvl_2024_full_train" evaluate_ds --mode 1 --out_dir "/home/sa53869/perco/res/outputs/Kodak_0.1250/"
